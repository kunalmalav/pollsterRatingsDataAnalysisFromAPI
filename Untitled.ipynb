# %% [markdown]
# # Analysis of pollsters rating by Five-Thirty-Eight
# ## Dr. Tirthajyoti Sarkar, Fremont, CA, June 2020

# %% [markdown]
# Five-Thirty-Eight especially prides itself on their unique strength of assigning a rating to every pollster, whose polling data they assimilate in their predictive models. They proclaim to do this based on the historical accuracy and methodology of each firm’s polls.
#
# They also publish the curated dataset on this ranking here: https://github.com/fivethirtyeight/data/tree/master/pollster-ratings
#
# Details on this dataset can be found here: https://projects.fivethirtyeight.com/pollster-ratings/

# %% [markdown]
# ##### Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.optimize import curve_fit

# %% [markdown]
# # Read in the dataset directly from the URL

# %%
url = "https://raw.githubusercontent.com/fivethirtyeight/data/master/pollster-ratings/pollster-ratings.csv"

# %%
try:
    df = pd.read_csv(url)
except:
    print("Could not retrieve the data!")

# %% [markdown]
# ##### Show column names

# %%
for c in df.columns:
    print(c,end=', ')
# Out:
# Rank, Pollster, Pollster Rating ID, Polls Analyzed, AAPOR/Roper, Banned by 538, Predictive Plus-Minus, 538 Grade, Mean-Reverted Bias, Races Called Correctly, Misses Outside MOE, Simple Average Error, Simple Expected Error, Simple Plus-Minus, Advanced Plus-Minus, Mean-Reverted Advanced Plus-Minus, # of Polls for Bias Analysis, Bias, House Effect, Average Distance from Polling Average (ADPA), Herding Penalty,

# %% [markdown]
# ##### Dataset info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 21 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Rank                                          517 non-null    int64
#  1   Pollster                                      517 non-null    object
#  2   Pollster Rating ID                            517 non-null    int64
#  3   Polls Analyzed                                517 non-null    int64
#  4   AAPOR/Roper                                   517 non-null    object
#  5   Banned by 538                                 517 non-null    object
#  6   Predictive Plus-Minus                         517 non-null    float64
#  7   538 Grade                                     517 non-null    object
#  8   Mean-Reverted Bias                            473 non-null    float64
#  9   Races Called Correctly                        517 non-null    float64
#  10  Misses Outside MOE                            517 non-null    float64
#  11  Simple Average Error                          517 non-null    float64
#  12  Simple Expected Error                         517 non-null    float64
#  13  Simple Plus-Minus                             517 non-null    float64
#  14  Advanced Plus-Minus                           517 non-null    float64
#  15  Mean-Reverted Advanced Plus-Minus             517 non-null    float64
#  16  # of Polls for Bias Analysis                  517 non-null    int64
#  17  Bias                                          473 non-null    float64
#  18  House Effect                                  455 non-null    float64
#  19  Average Distance from Polling Average (ADPA)  409 non-null    float64
#  20  Herding Penalty                               517 non-null    float64
# dtypes: float64(13), int64(4), object(4)
# memory usage: 84.9+ KB

# %% [markdown]
# ##### Rename a column to remove extra spaces

# %%
df.rename(columns={'Predictive    Plus-Minus':'Predictive Plus-Minus'},inplace=True)

# %% [markdown]
# ##### Convert Races Called Correctly to float from string

# %%
df['Races Called Correctly'][:3]
# Out:
# 0    0.747368
# 1    0.811321
# 2    0.886364
# Name: Races Called Correctly, dtype: float64

# %%
def percent_to_float(x):
    """
    Converts percentage to float
    """
    return float(x[:-1])/100

# %%
df['Races Called Correctly']=df['Races Called Correctly'].apply(percent_to_float)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df['Races Called Correctly']=df['Races Called Correctly'].apply(percent_to_float)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[8], line 5, in percent_to_float(x)
#       1 def percent_to_float(x):
#       2     """
#       3     Converts percentage to float
#       4     """
# ----> 5     return float(x[:-1])/100
#
# TypeError: 'float' object is not subscriptable

# %%
df['Races Called Correctly'][:3]
# Out:
# 0    0.747368
# 1    0.811321
# 2    0.886364
# Name: Races Called Correctly, dtype: float64

# %% [markdown]
# ##### Extract partisan bias from the Bias column

# %%
def bias_party_id(x):
    """
    Returns a string indicating partisan bias
    """
    if x is np.nan: return "No data"
    x = str(x)
    if x[0]=='D': return "Democratic"
    else: return 'Republican'

# %%
def bias_party_degree(x):
    """
    Returns a string indicating partisan bias
    """
    if x is np.nan: return np.nan
    x = str(x)
    return float(x[3:])

# %%
df['Partisan Bias']=df['Bias'].apply(bias_party_id)

# %%
df['Partisan Bias Degree']=df['Bias'].apply(bias_party_degree)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df['Partisan Bias Degree']=df['Bias'].apply(bias_party_degree)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[16], line 7, in bias_party_degree(x)
#       5 if x is np.nan: return np.nan
#       6 x = str(x)
# ----> 7 return float(x[3:])
#
# ValueError: could not convert string to float: ''

# %%
df[['Pollster','Bias','Partisan Bias','Partisan Bias Degree']].sample(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df[['Pollster','Bias','Partisan Bias','Partisan Bias Degree']].sample(5)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Partisan Bias Degree'] not in index"

# %% [markdown]
# ##### Examine and quantize the 538 Grade column

# %%
df['538 Grade'].unique()
# Out:
# array(['A+', 'A/B', 'A', 'A-', 'F', 'B+', 'B/C', 'B', 'B-', 'C+', 'C',
#        'C/D', 'C-'], dtype=object)

# %%
plt.figure(figsize=(12,4))
plt.title("Pollster grade counts",fontsize=18)
plt.bar(x=df['538 Grade'].unique(),
        height=df['538 Grade'].value_counts(),
       color='red',alpha=0.6,edgecolor='k',linewidth=2.5)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(True)
plt.show()

# %%
def grade_numeric(x):
    """
    Quantizes the letter grades
    """
    if x[0]=='A': return 4
    if x[0]=='B': return 3
    if x[0]=='C': return 2
    if x[0]=='D': return 1
    else: return 0

# %%
df['Numeric grade']=df['538 Grade'].apply(grade_numeric)

# %%
df['Numeric grade'].value_counts()
# Out:
# 3    412
# 4     68
# 2     26
# 0     11
# Name: Numeric grade, dtype: int64

# %% [markdown]
# ##### Boxplots

# %%
def custom_boxplot(x,y,rot=90):
    plt.figure(figsize=(12,4))
    plt.title("Boxplot of \"{}\" by \"{}\"".format(y,x),fontsize=17)
    sns.boxplot(x=x,y=y,data=df)
    plt.xticks(rotation=rot,fontsize=12)
    plt.yticks(fontsize=13)
    plt.xlabel(x,fontsize=15)
    plt.ylabel(y+'\n',fontsize=15)
    plt.show()

# %%
custom_boxplot(x='Methodology',y='Simple Average Error')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 custom_boxplot(x='Methodology',y='Simple Average Error')
#
# Cell In[25], line 4, in custom_boxplot(x, y, rot)
#       2 plt.figure(figsize=(12,4))
#       3 plt.title("Boxplot of \"{}\" by \"{}\"".format(y,x),fontsize=17)
# ----> 4 sns.boxplot(x=x,y=y,data=df)
#       5 plt.xticks(rotation=rot,fontsize=12)
#       6 plt.yticks(fontsize=13)
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
#    2233                           width, dodge, fliersize, linewidth)
#    2235     if ax is None:
#    2236         ax = plt.gca()
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:785, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     781 def __init__(self, x, y, hue, data, order, hue_order,
#     782              orient, color, palette, saturation,
#     783              width, dodge, fliersize, linewidth):
# --> 785     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     786     self.establish_colors(color, palette, saturation)
#     788     self.dodge = dodge
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'Methodology'

# %%
custom_boxplot(x='Methodology',y='Predictive Plus-Minus')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 custom_boxplot(x='Methodology',y='Predictive Plus-Minus')
#
# Cell In[25], line 4, in custom_boxplot(x, y, rot)
#       2 plt.figure(figsize=(12,4))
#       3 plt.title("Boxplot of \"{}\" by \"{}\"".format(y,x),fontsize=17)
# ----> 4 sns.boxplot(x=x,y=y,data=df)
#       5 plt.xticks(rotation=rot,fontsize=12)
#       6 plt.yticks(fontsize=13)
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
#    2233                           width, dodge, fliersize, linewidth)
#    2235     if ax is None:
#    2236         ax = plt.gca()
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:785, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     781 def __init__(self, x, y, hue, data, order, hue_order,
#     782              orient, color, palette, saturation,
#     783              width, dodge, fliersize, linewidth):
# --> 785     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     786     self.establish_colors(color, palette, saturation)
#     788     self.dodge = dodge
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'Methodology'

# %%
custom_boxplot(x='Partisan Bias',y='Races Called Correctly',rot=0)

# %%
custom_boxplot(x='Partisan Bias',y='Advanced Plus-Minus')

# %%
custom_boxplot(x='NCPP / AAPOR / Roper',y='Races Called Correctly',rot=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 custom_boxplot(x='NCPP / AAPOR / Roper',y='Races Called Correctly',rot=0)
#
# Cell In[25], line 4, in custom_boxplot(x, y, rot)
#       2 plt.figure(figsize=(12,4))
#       3 plt.title("Boxplot of \"{}\" by \"{}\"".format(y,x),fontsize=17)
# ----> 4 sns.boxplot(x=x,y=y,data=df)
#       5 plt.xticks(rotation=rot,fontsize=12)
#       6 plt.yticks(fontsize=13)
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
#    2233                           width, dodge, fliersize, linewidth)
#    2235     if ax is None:
#    2236         ax = plt.gca()
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:785, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     781 def __init__(self, x, y, hue, data, order, hue_order,
#     782              orient, color, palette, saturation,
#     783              width, dodge, fliersize, linewidth):
# --> 785     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     786     self.establish_colors(color, palette, saturation)
#     788     self.dodge = dodge
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'NCPP / AAPOR / Roper'

# %%
custom_boxplot(x='NCPP / AAPOR / Roper',y='Advanced Plus-Minus',rot=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 custom_boxplot(x='NCPP / AAPOR / Roper',y='Advanced Plus-Minus',rot=0)
#
# Cell In[25], line 4, in custom_boxplot(x, y, rot)
#       2 plt.figure(figsize=(12,4))
#       3 plt.title("Boxplot of \"{}\" by \"{}\"".format(y,x),fontsize=17)
# ----> 4 sns.boxplot(x=x,y=y,data=df)
#       5 plt.xticks(rotation=rot,fontsize=12)
#       6 plt.yticks(fontsize=13)
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
#    2233                           width, dodge, fliersize, linewidth)
#    2235     if ax is None:
#    2236         ax = plt.gca()
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:785, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     781 def __init__(self, x, y, hue, data, order, hue_order,
#     782              orient, color, palette, saturation,
#     783              width, dodge, fliersize, linewidth):
# --> 785     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     786     self.establish_colors(color, palette, saturation)
#     788     self.dodge = dodge
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'NCPP / AAPOR / Roper'

# %% [markdown]
# ##### Scatter and regression plots

# %%
def custom_scatter(x,y,data=df,pos=(0,0),regeqn=True):
    """
    Plots customized scatter plots with regression fit using Seaborn
    """    
    sns.lmplot(x=x,y=y,data=data,height=4,aspect=1.5,
       scatter_kws={'color':'yellow','edgecolor':'k','s':100},
              line_kws={'linewidth':3,'color':'red','linestyle':'--'})
    
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.xlabel(x,fontsize=15)
    plt.ylabel(y+'\n',fontsize=15)
    ax = plt.gca()
    ax.set_title("Regression fit of \"{}\" vs. \"{}\"".format(x,y),fontsize=15)
    
    if (regeqn):
        slope, intercept, r_value, p_value, std_err = stats.linregress(df[x],df[y])
        r_squared = r_value**2
        eqn= "$y$={0:.3f}$x$+{1:.3f},\n$R^2$:{2:.3f}".format(slope,intercept,r_squared)
        plt.annotate(s=eqn,xy=pos,fontsize=13)

# %%
custom_scatter(x='Races Called Correctly',
               y='Predictive Plus-Minus',
              pos=(0.05,-1.5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 custom_scatter(x='Races Called Correctly',
#       2                y='Predictive Plus-Minus',
#       3               pos=(0.05,-1.5))
#
# Cell In[32], line 20, in custom_scatter(x, y, data, pos, regeqn)
#      18 r_squared = r_value**2
#      19 eqn= "$y$={0:.3f}$x$+{1:.3f},\n$R^2$:{2:.3f}".format(slope,intercept,r_squared)
# ---> 20 plt.annotate(s=eqn,xy=pos,fontsize=13)
#
# TypeError: annotate() missing 1 required positional argument: 'text'

# %%
custom_scatter(x='Numeric grade',
               y='Simple Average Error',
              pos=(0,20))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 custom_scatter(x='Numeric grade',
#       2                y='Simple Average Error',
#       3               pos=(0,20))
#
# Cell In[32], line 20, in custom_scatter(x, y, data, pos, regeqn)
#      18 r_squared = r_value**2
#      19 eqn= "$y$={0:.3f}$x$+{1:.3f},\n$R^2$:{2:.3f}".format(slope,intercept,r_squared)
# ---> 20 plt.annotate(s=eqn,xy=pos,fontsize=13)
#
# TypeError: annotate() missing 1 required positional argument: 'text'

# %%
df.columns
# Out:
# Index(['Rank', 'Pollster', 'Pollster Rating ID', 'Polls Analyzed',
#        'AAPOR/Roper', 'Banned by 538', 'Predictive Plus-Minus', '538 Grade',
#        'Mean-Reverted Bias', 'Races Called Correctly', 'Misses Outside MOE',
#        'Simple Average Error', 'Simple Expected Error', 'Simple Plus-Minus',
#        'Advanced Plus-Minus', 'Mean-Reverted Advanced Plus-Minus',
#        '# of Polls for Bias Analysis', 'Bias', 'House Effect',
#        'Average Distance from Polling Average (ADPA)', 'Herding Penalty',
#        'Partisan Bias', 'Numeric grade'],
#       dtype='object')

# %%
df_2 = df.dropna()
filtered = df_2[df_2['# of Polls']>100]
custom_scatter(x='# of Polls for Bias Analysis',
              y='Partisan Bias Degree',
              data=filtered,regeqn=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '# of Polls'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 2
#       1 df_2 = df.dropna()
# ----> 2 filtered = df_2[df_2['# of Polls']>100]
#       3 custom_scatter(x='# of Polls for Bias Analysis',
#       4               y='Partisan Bias Degree',
#       5               data=filtered,regeqn=False)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: '# of Polls'

# %%
x = df_2['# of Polls for Bias Analysis']
y = df_2['Partisan Bias Degree']
            
plt.scatter(x,y,color='yellow',edgecolors='k',s=100)

def func(x, a, b, c):
    return a * np.exp(-b *0.1*x) + c
popt, pcov = curve_fit(func, x, y)
y_fit = func(x,popt[0],popt[1],popt[2])
plt.scatter(x,y_fit,color='red',alpha=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Partisan Bias Degree'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 2
#       1 x = df_2['# of Polls for Bias Analysis']
# ----> 2 y = df_2['Partisan Bias Degree']
#       4 plt.scatter(x,y,color='yellow',edgecolors='k',s=100)
#       6 def func(x, a, b, c):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Partisan Bias Degree'

# %%
plt.scatter(np.log10(np.abs(x)),np.log10(np.abs(y)),color='yellow',edgecolors='k',s=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 plt.scatter(np.log10(np.abs(x)),np.log10(np.abs(y)),color='yellow',edgecolors='k',s=100)
#
# NameError: name 'y' is not defined

# %%
popt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 popt
#
# NameError: name 'popt' is not defined

# %%
filtered = df[df['# of Polls']>20]
plt.title("Histogram of the \'# of Polls\'",fontsize=16)
plt.hist(filtered['# of Polls'],color='orange',edgecolor='k')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

filtered =filtered[filtered['# of Polls']<400]
custom_scatter(x='# of Polls',
               y='Predictive Plus-Minus',
               pos = (200,-1),
               data=filtered)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '# of Polls'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 filtered = df[df['# of Polls']>20]
#       2 plt.title("Histogram of the \'# of Polls\'",fontsize=16)
#       3 plt.hist(filtered['# of Polls'],color='orange',edgecolor='k')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: '# of Polls'

# %%
df_scores = df[['Predictive Plus-Minus','Races Called Correctly',
                'Simple Average Error','Advanced Plus-Minus',
               'Numeric grade']]

# %%
sns.pairplot(data=df_scores,
             plot_kws={'color':'red','edgecolor':'k'},
             diag_kws={'color':'blue','edgecolor':'k'})

# %% [markdown]
# ##### Filtering And Sorting

# %%
df_sorted = df[df['# of Polls']>50].sort_values(by=['Advanced Plus-Minus'])[:10]
df_sorted[['Pollster','# of Polls','Advanced Plus-Minus','Partisan Bias','538 Grade']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '# of Polls'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df_sorted = df[df['# of Polls']>50].sort_values(by=['Advanced Plus-Minus'])[:10]
#       2 df_sorted[['Pollster','# of Polls','Advanced Plus-Minus','Partisan Bias','538 Grade']]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: '# of Polls'

# %%
df['House Effect']
# Out:
# 0       0.700506
# 1      -0.343495
# 2       0.632896
# 3      -0.526230
# 4      -0.199840
#          ...
# 512    11.670131
# 513     8.833333
# 514     4.727778
# 515    10.899998
# 516   -27.666667
# Name: House Effect, Length: 517, dtype: float64
